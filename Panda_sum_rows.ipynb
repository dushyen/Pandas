# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
fraud = pd.read_csv("creditcard.csv")

# %%
##a= fraud.iloc[:, -4:-1].sum(axis=1)
a= fraud.iloc[:,  1:29].sum(axis=1)
a
# Out:
# 0         3.081757
# 1         4.439726
# 2         1.091311
# 3        -2.409596
# 4         5.378728
# 5         2.924822
# 6        -0.737258
# 7        -1.209385
# 8         5.102096
# 9         4.339088
# 10       -2.563052
# 11        7.927346
# 12       -5.088011
# 13        2.593879
# 14        4.935753
# 15        1.186324
# 16        3.229295
# 17        0.017042
# 18       -5.410553
# 19       -3.748763
# 20       -1.203899
# 21        4.556731
# 22        2.821121
# 23        4.466467
# 24        6.461998
# 25       -1.302643
# 26        4.594895
# 27       -1.646827
# 28        4.752320
# 29        4.298302
#             ...
# 284777    0.441996
# 284778   -1.542301
# 284779    4.498258
# 284780    5.098988
# 284781    1.962833
# 284782    8.965835
# 284783    6.112845
# 284784    5.264321
# 284785    2.768079
# 284786    1.689699
# 284787   -6.138741
# 284788    0.616812
# 284789   -0.510370
# 284790   -1.866957
# 284791   -4.421005
# 284792    1.477556
# ...

# %%
print (fraud.columns)
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class', 'tran_id'],
#       dtype='object')

# %%
fraud[['Class', 'Time']]
df['elderly'] = np.where(df['age']>=50, 'yes', 'no')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a5fa33efaf68> in <module>()
#       1
#       2 fraud[['Class', 'Time']]
# ----> 3 df['elderly'] = np.where(df['age']>=50, 'yes', 'no')
#
# NameError: name 'df' is not defined

# %%
fraud['class1'] = np.where(fraud['Class']==1, 'yes', 'no')
fraud['class1'].head
# Out:
# <bound method Series.head of 0         no
# 1         no
# 2         no
# 3         no
# 4         no
# 5         no
# 6         no
# 7         no
# 8         no
# 9         no
# 10        no
# 11        no
# 12        no
# 13        no
# 14        no
# 15        no
# 16        no
# 17        no
# 18        no
# 19        no
# 20        no
# 21        no
# 22        no
# 23        no
# 24        no
# 25        no
# 26        no
# 27        no
# 28        no
# 29        no
#           ..
# 284777    no
# 284778    no
# 284779    no
# 284780    no
# 284781    no
# 284782    no
# 284783    no
# 284784    no
# 284785    no
# 284786    no
# 284787    no
# 284788    no
# 284789    no
# 284790    no
# 284791    no
# 284792    no
# 284793    no
# 284794    no
# 284795    no
# 284796    no
# 284797    no
# 284798    no
# 284799    no
# 284800    no
# 284801    no
# 284802    no
# 284803    no
# 284804    no
# 284805    no
# 284806    no
# Name: class1, dtype: object>

# %%
fraud_1 = fraud[['Class', 'Time','V1','V2','V3']]

# %%
fraud_2 =  fraud_1.iloc[:,3:2].sum(axis=1)

# %%
fraud_1["total1"] = fraud_1["V1"] + fraud_1["V2"] + fraud_1["V3"]
fraud_1["total"]= fraud_1.iloc[:,2:5].sum(axis=1)
fraud_1 [['Class', 'Time','total','V1','total1']]
# Out:
# /root/anaconda2/envs/py34/lib/python3.4/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /root/anaconda2/envs/py34/lib/python3.4/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#         Class    Time      total         V1     total1
# 0           0       0   1.103758  -1.359807   1.103758
# 1           0       0   1.624488   1.191857   1.624488
# ...

# %%
##fraud_1.loc[:3]
##fraud_1.ix[:3]
##fraud_1.iloc[:1]
fraud_1.iloc[:,2:5]
# Out:
#                V1         V2        V3
# 0       -1.359807  -0.072781  2.536347
# 1        1.191857   0.266151  0.166480
# 2       -1.358354  -1.340163  1.773209
# 3       -0.966272  -0.185226  1.792993
# 4       -1.158233   0.877737  1.548718
# 5       -0.425966   0.960523  1.141109
# 6        1.229658   0.141004  0.045371
# 7       -0.644269   1.417964  1.074380
# 8       -0.894286   0.286157 -0.113192
# 9       -0.338262   1.119593  1.044367
# 10       1.449044  -1.176339  0.913860
# 11       0.384978   0.616109 -0.874300
# 12       1.249999  -1.221637  0.383930
# 13       1.069374   0.287722  0.828613
# 14      -2.791855  -0.327771  1.641750
# 15      -0.752417   0.345485  2.057323
# 16       1.103215  -0.040296  1.267332
# 17      -0.436905   0.918966  0.924591
# 18      -5.401258  -5.450148  1.186305
# 19       1.492936  -1.029346  0.454795
# 20       0.694885  -1.361819  1.029221
# 21       0.962496   0.328461 -0.171479
# 22       1.166616   0.502120 -0.067300
# ...

# %%
fraud_3 = fraud
fraud_3["total"]= fraud_3.iloc[:,1:29].sum(axis=1)
fraud_3["total1"] = fraud_3["V1"] + fraud_3["V2"] + fraud_3["V3"] +  fraud_3["V4"] + fraud_3["V5"] + fraud_3["V6"]
fraud_3 [['Class', 'Time','tran_id','total','total1']]
# Out:
#         Class    Time  tran_id     total     total1
# 0           0       0        1  3.081757   2.605981
# 1           0       0        2  4.439726   2.050299
# 2           0       1        3  1.091311   0.751773
# 3           0       1        4 -2.409596   1.015099
# 4           0       2        5  5.378728   1.359984
# 5           0       2        6  2.924822   1.898674
# 6           0       4        7 -0.737258   3.083234
# 7           0       7        8 -1.209385   2.732928
# 8           0       7        9  5.102096   5.398569
# 9           0       9       10  4.339088   1.856111
# 10          0      10       11 -2.563052  -2.789637
# 11          0      10       12  7.927346   6.274381
# 12          0      10       13 -5.088011  -3.061256
# 13          0      11       14  2.593879   5.057375
# 14          0      12       15  4.935753   0.960605
# 15          0      12       16  1.186324  -1.054496
# 16          0      12       17  3.229295   3.171415
# ...
